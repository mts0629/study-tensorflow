# %%
# !pip install -q -U keras-tuner

# %%
import tensorflow as tf
from tensorflow import keras

import keras_tuner as kt
# Out:
# Using TensorFlow backend

# %%
(img_train, label_train), (img_test, label_test) = \
    keras.datasets.fashion_mnist.load_data()

# Normalize pixel values
img_train = img_train.astype("float32") / 255.0
img_test = img_test.astype("float32") / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
def model_builder(hp):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape=(28, 28)))

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units = hp.Int("units", min_value=32, max_value=512, step=32)
    model.add(keras.layers.Dense(units=hp_units, activation="relu"))
    model.add(keras.layers.Dense(10))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice("learning_rate", values=[1e-2, 1e-3, 1e-4])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"]
    )
    return model

# %%
# Use a Hyperband tuner
tuner = kt.Hyperband(model_builder,
                     objective="val_accuracy",
                     max_epochs=10,
                     factor=3,
                     directory="my_dir",
                     project_name="intro_to_kt")

stop_early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)

# %%
tuner.search(
    img_train, label_train,
    epochs=50, validation_split=0.2,
    callbacks=[stop_early]
)

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete.  The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimzer
is {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 30 Complete [00h 01m 27s]
# val_accuracy: 0.8610000014305115
#
# Best val_accuracy So Far: 0.893750011920929
# Total elapsed time: 00h 24m 12s
#
# The hyperparameter search is complete.  The optimal number of units in the first densely-connected
# layer is 448 and the optimal learning rate for the optimzer
# is 0.001.

# %%
# Build the model with the optimal hyperparameters and train it on the data
# for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(img_train, label_train, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history["val_accuracy"]
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print("Best epoch: %d" % (best_epoch,))
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.4960 - accuracy: 0.8237 - val_loss: 0.3850 - val_accuracy: 0.8584
# Epoch 2/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.3690 - accuracy: 0.8655 - val_loss: 0.4030 - val_accuracy: 0.8543
# Epoch 3/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.3322 - accuracy: 0.8776 - val_loss: 0.3432 - val_accuracy: 0.8745
# Epoch 4/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.3050 - accuracy: 0.8864 - val_loss: 0.3308 - val_accuracy: 0.8803
# Epoch 5/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2869 - accuracy: 0.8942 - val_loss: 0.3436 - val_accuracy: 0.8737
# Epoch 6/50
# 1500/1500 [==============================] - 14s 9ms/step - loss: 0.2683 - accuracy: 0.9001 - val_loss: 0.3214 - val_accuracy: 0.8849
# Epoch 7/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2577 - accuracy: 0.9048 - val_loss: 0.3198 - val_accuracy: 0.8845
# Epoch 8/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2450 - accuracy: 0.9097 - val_loss: 0.3189 - val_accuracy: 0.8856
# Epoch 9/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2330 - accuracy: 0.9119 - val_loss: 0.3167 - val_accuracy: 0.8887
# Epoch 10/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2242 - accuracy: 0.9151 - val_loss: 0.3077 - val_accuracy: 0.8912
# Epoch 11/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2116 - accuracy: 0.9199 - val_loss: 0.3272 - val_accuracy: 0.8916
# Epoch 12/50
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2040 - accuracy: 0.9223 - val_loss: 0.3321 - val_accuracy: 0.8863
# Epoch 13/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1974 - accuracy: 0.9257 - val_loss: 0.3365 - val_accuracy: 0.8929
# Epoch 14/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1905 - accuracy: 0.9295 - val_loss: 0.3370 - val_accuracy: 0.8877
# Epoch 15/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1825 - accuracy: 0.9310 - val_loss: 0.3442 - val_accuracy: 0.8926
# Epoch 16/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1802 - accuracy: 0.9334 - val_loss: 0.3402 - val_accuracy: 0.8909
# Epoch 17/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1720 - accuracy: 0.9361 - val_loss: 0.3413 - val_accuracy: 0.8904
# Epoch 18/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1666 - accuracy: 0.9380 - val_loss: 0.3483 - val_accuracy: 0.8947
# Epoch 19/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1640 - accuracy: 0.9395 - val_loss: 0.3465 - val_accuracy: 0.8939
# Epoch 20/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1552 - accuracy: 0.9427 - val_loss: 0.3492 - val_accuracy: 0.8917
# Epoch 21/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1517 - accuracy: 0.9428 - val_loss: 0.3870 - val_accuracy: 0.8863
# Epoch 22/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1464 - accuracy: 0.9448 - val_loss: 0.3648 - val_accuracy: 0.8914
# Epoch 23/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1436 - accuracy: 0.9455 - val_loss: 0.3636 - val_accuracy: 0.8917
# Epoch 24/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1391 - accuracy: 0.9485 - val_loss: 0.3792 - val_accuracy: 0.8880
# Epoch 25/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1353 - accuracy: 0.9495 - val_loss: 0.3619 - val_accuracy: 0.8966
# Epoch 26/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1282 - accuracy: 0.9519 - val_loss: 0.3754 - val_accuracy: 0.8948
# Epoch 27/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1291 - accuracy: 0.9517 - val_loss: 0.3675 - val_accuracy: 0.8938
# Epoch 28/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1226 - accuracy: 0.9535 - val_loss: 0.4079 - val_accuracy: 0.8894
# Epoch 29/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1210 - accuracy: 0.9543 - val_loss: 0.3756 - val_accuracy: 0.8992
# Epoch 30/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1186 - accuracy: 0.9562 - val_loss: 0.4042 - val_accuracy: 0.8926
# Epoch 31/50
# 1500/1500 [==============================] - 14s 9ms/step - loss: 0.1155 - accuracy: 0.9561 - val_loss: 0.4150 - val_accuracy: 0.8947
# Epoch 32/50
# 1500/1500 [==============================] - 14s 9ms/step - loss: 0.1115 - accuracy: 0.9589 - val_loss: 0.4165 - val_accuracy: 0.8973
# Epoch 33/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1102 - accuracy: 0.9589 - val_loss: 0.4659 - val_accuracy: 0.8888
# Epoch 34/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1077 - accuracy: 0.9608 - val_loss: 0.4228 - val_accuracy: 0.8924
# Epoch 35/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1009 - accuracy: 0.9616 - val_loss: 0.4447 - val_accuracy: 0.8898
# Epoch 36/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1015 - accuracy: 0.9617 - val_loss: 0.4635 - val_accuracy: 0.8937
# Epoch 37/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0999 - accuracy: 0.9630 - val_loss: 0.4233 - val_accuracy: 0.8986
# Epoch 38/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0985 - accuracy: 0.9631 - val_loss: 0.4425 - val_accuracy: 0.8925
# Epoch 39/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0926 - accuracy: 0.9655 - val_loss: 0.4684 - val_accuracy: 0.8884
# Epoch 40/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0909 - accuracy: 0.9660 - val_loss: 0.4746 - val_accuracy: 0.8935
# Epoch 41/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0932 - accuracy: 0.9655 - val_loss: 0.4922 - val_accuracy: 0.8876
# Epoch 42/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0874 - accuracy: 0.9676 - val_loss: 0.4704 - val_accuracy: 0.8903
# Epoch 43/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0857 - accuracy: 0.9678 - val_loss: 0.4859 - val_accuracy: 0.8902
# Epoch 44/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0827 - accuracy: 0.9684 - val_loss: 0.4986 - val_accuracy: 0.8923
# Epoch 45/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0813 - accuracy: 0.9703 - val_loss: 0.4937 - val_accuracy: 0.8907
# Epoch 46/50
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0840 - accuracy: 0.9685 - val_loss: 0.5224 - val_accuracy: 0.8930
# Epoch 47/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0787 - accuracy: 0.9707 - val_loss: 0.5359 - val_accuracy: 0.8909
# Epoch 48/50
# 1500/1500 [==============================] - 14s 9ms/step - loss: 0.0802 - accuracy: 0.9697 - val_loss: 0.5305 - val_accuracy: 0.8922
# Epoch 49/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0793 - accuracy: 0.9703 - val_loss: 0.5333 - val_accuracy: 0.8940
# Epoch 50/50
# 1500/1500 [==============================] - 14s 9ms/step - loss: 0.0760 - accuracy: 0.9717 - val_loss: 0.5574 - val_accuracy: 0.8880
# Best epoch: 29

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(img_train, label_train, epochs=best_epoch, validation_split=0.2)
# Out:
# Epoch 1/29
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.4926 - accuracy: 0.8249 - val_loss: 0.4042 - val_accuracy: 0.8525
# Epoch 2/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.3696 - accuracy: 0.8644 - val_loss: 0.3873 - val_accuracy: 0.8577
# Epoch 3/29
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.3313 - accuracy: 0.8781 - val_loss: 0.3481 - val_accuracy: 0.8702
# Epoch 4/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.3033 - accuracy: 0.8871 - val_loss: 0.3296 - val_accuracy: 0.8813
# Epoch 5/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2868 - accuracy: 0.8934 - val_loss: 0.3446 - val_accuracy: 0.8738
# Epoch 6/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2713 - accuracy: 0.8983 - val_loss: 0.3382 - val_accuracy: 0.8794
# Epoch 7/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2553 - accuracy: 0.9055 - val_loss: 0.3298 - val_accuracy: 0.8840
# Epoch 8/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2461 - accuracy: 0.9086 - val_loss: 0.3240 - val_accuracy: 0.8845
# Epoch 9/29
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2340 - accuracy: 0.9137 - val_loss: 0.3285 - val_accuracy: 0.8821
# Epoch 10/29
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2242 - accuracy: 0.9160 - val_loss: 0.3137 - val_accuracy: 0.8898
# Epoch 11/29
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2170 - accuracy: 0.9194 - val_loss: 0.3169 - val_accuracy: 0.8897
# Epoch 12/29
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.2081 - accuracy: 0.9217 - val_loss: 0.3137 - val_accuracy: 0.8914
# Epoch 13/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1996 - accuracy: 0.9262 - val_loss: 0.3300 - val_accuracy: 0.8882
# Epoch 14/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1934 - accuracy: 0.9282 - val_loss: 0.3191 - val_accuracy: 0.8932
# Epoch 15/29
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.1889 - accuracy: 0.9300 - val_loss: 0.3468 - val_accuracy: 0.8831
# Epoch 16/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1804 - accuracy: 0.9328 - val_loss: 0.3222 - val_accuracy: 0.8927
# Epoch 17/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1759 - accuracy: 0.9331 - val_loss: 0.3324 - val_accuracy: 0.8895
# Epoch 18/29
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1666 - accuracy: 0.9374 - val_loss: 0.3435 - val_accuracy: 0.8904
# Epoch 19/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1634 - accuracy: 0.9385 - val_loss: 0.3348 - val_accuracy: 0.8970
# Epoch 20/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1597 - accuracy: 0.9393 - val_loss: 0.3536 - val_accuracy: 0.8907
# Epoch 21/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1532 - accuracy: 0.9422 - val_loss: 0.3481 - val_accuracy: 0.8962
# Epoch 22/29
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.1500 - accuracy: 0.9426 - val_loss: 0.3628 - val_accuracy: 0.8891
# Epoch 23/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1429 - accuracy: 0.9470 - val_loss: 0.3740 - val_accuracy: 0.8947
# Epoch 24/29
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1409 - accuracy: 0.9473 - val_loss: 0.3396 - val_accuracy: 0.8967
# Epoch 25/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1367 - accuracy: 0.9490 - val_loss: 0.4028 - val_accuracy: 0.8869
# Epoch 26/29
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.1297 - accuracy: 0.9515 - val_loss: 0.3807 - val_accuracy: 0.8915
# Epoch 27/29
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1317 - accuracy: 0.9514 - val_loss: 0.4437 - val_accuracy: 0.8807
# Epoch 28/29
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.1249 - accuracy: 0.9539 - val_loss: 0.3858 - val_accuracy: 0.8925
# Epoch 29/29
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1200 - accuracy: 0.9551 - val_loss: 0.3863 - val_accuracy: 0.8938

# %%
eval_result = hypermodel.evaluate(img_test, label_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4440 - accuracy: 0.8868
# [test loss, test accuracy]: [0.4439612329006195, 0.8867999911308289]

# %%
# !ls my_dir/intro_to_kt

# !ls my_dir/intro_to_kt/trial_0000
# Out:
# oracle.json  trial_0003  trial_0007  trial_0011  trial_0015  trial_0019  trial_0023  trial_0027
# trial_0000   trial_0004  trial_0008  trial_0012  trial_0016  trial_0020  trial_0024  trial_0028
# trial_0001   trial_0005  trial_0009  trial_0013  trial_0017  trial_0021  trial_0025  trial_0029
# trial_0002   trial_0006  trial_0010  trial_0014  trial_0018  trial_0022  trial_0026  tuner0.json
# checkpoint  checkpoint.data-00000-of-00001  checkpoint.index  trial.json
